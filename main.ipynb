# %%
pip install ultralyticsplus==0.0.23 ultralytics==8.0.21
# Out:
# Requirement already satisfied: ultralyticsplus==0.0.23 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.0.23)
# Requirement already satisfied: ultralytics==8.0.21 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (8.0.21)
# Requirement already satisfied: sahi<0.12.0,>=0.11.11 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralyticsplus==0.0.23) (0.11.12)
# Requirement already satisfied: fire in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralyticsplus==0.0.23) (0.5.0)
# Requirement already satisfied: huggingface-hub>=0.12.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralyticsplus==0.0.23) (0.13.2)
# Requirement already satisfied: pandas in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralyticsplus==0.0.23) (1.5.3)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (6.0)
# Requirement already satisfied: torchvision>=0.8.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (0.15.1)
# Requirement already satisfied: Pillow>=7.1.2 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (9.2.0)
# Requirement already satisfied: matplotlib>=3.2.2 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (3.7.1)
# Requirement already satisfied: torch>=1.7.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (2.0.0)
# Requirement already satisfied: tensorboard>=2.4.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (2.12.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (4.65.0)
# Requirement already satisfied: ipython in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (8.5.0)
# Requirement already satisfied: sentry-sdk in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (1.17.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (0.1.1.post2209072238)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (1.10.1)
# Requirement already satisfied: psutil in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (5.9.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (4.7.0.72)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (1.24.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (0.12.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ultralytics==8.0.21) (2.28.1)
# Requirement already satisfied: filelock in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.23) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (4.39.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from matplotlib>=3.2.2->ultralytics==8.0.21) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas->ultralyticsplus==0.0.23) (2022.7.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.23.0->ultralytics==8.0.21) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.23.0->ultralytics==8.0.21) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.23.0->ultralytics==8.0.21) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.23.0->ultralytics==8.0.21) (1.26.11)
# Requirement already satisfied: pybboxes==0.1.6 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.23) (0.1.6)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.23) (2.0.1)
# Requirement already satisfied: click==8.0.4 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.23) (8.0.4)
# Requirement already satisfied: terminaltables in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.23) (3.1.10)
# Requirement already satisfied: colorama in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click==8.0.4->sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.23) (0.4.5)
# Requirement already satisfied: absl-py>=0.4 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (1.4.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (0.40.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (65.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (1.51.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (2.16.2)
# Requirement already satisfied: protobuf>=3.19.6 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (4.22.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tensorboard>=2.4.1->ultralytics==8.0.21) (0.4.6)
# Requirement already satisfied: networkx in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch>=1.7.0->ultralytics==8.0.21) (3.0)
# Requirement already satisfied: sympy in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch>=1.7.0->ultralytics==8.0.21) (1.11.1)
# Requirement already satisfied: jinja2 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch>=1.7.0->ultralytics==8.0.21) (3.1.2)
# Requirement already satisfied: six in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fire->ultralyticsplus==0.0.23) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from fire->ultralyticsplus==0.0.23) (2.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (5.4.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (3.0.31)
# Requirement already satisfied: pickleshare in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (2.13.0)
# Requirement already satisfied: decorator in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (0.5.1)
# Requirement already satisfied: backcall in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from ipython->ultralytics==8.0.21) (0.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.21) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.21) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.21) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->ultralytics==8.0.21) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jedi>=0.16->ipython->ultralytics==8.0.21) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->ultralytics==8.0.21) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->ultralytics==8.0.21) (2.1.2)
# Requirement already satisfied: asttokens in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython->ultralytics==8.0.21) (2.0.8)
# Requirement already satisfied: executing in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython->ultralytics==8.0.21) (1.1.1)
# Requirement already satisfied: pure-eval in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from stack-data->ipython->ultralytics==8.0.21) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sympy->torch>=1.7.0->ultralytics==8.0.21) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.21) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\somas\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.4.1->ultralytics==8.0.21) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: C:\Users\somas\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from ultralyticsplus import YOLO, render_result

# load model
model = YOLO('keremberke/yolov8n-pothole-segmentation')
# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
image = 'Ramaiah\pothole_1.jpg'
# perform inference
results = model.predict(image)

# observe results
print(results[0].boxes)
print(results[0].masks)
render = render_result(model=model, image=image, result=results[0])
render.show()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\tempfile.py:256, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     255 try:
# --> 256     fd = _os.open(file, flags, 0o600)
#     257 except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\tmpb1p24v0h'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\somas\OneDrive\Desktop\Projects\Ramaiah\main.ipynb Cell 2 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/somas/OneDrive/Desktop/Projects/Ramaiah/main.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from ultralyticsplus import YOLO, render_result
#       <a href='vscode-notebook-cell:/c%3A/Users/somas/OneDrive/Desktop/Projects/Ramaiah/main.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> # load model
#       <a href='vscode-notebook-cell:/c%3A/Users/somas/OneDrive/Desktop/Projects/Ramaiah/main.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> model = YOLO('keremberke/yolov8n-pothole-segmentation')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralyticsplus\__init__.py:2
#       1 from .hf_utils import download_from_hub, push_to_hfhub
# ----> 2 from .ultralytics_utils import YOLO, postprocess_classify_output, render_result
#       4 __version__ = "0.0.23"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralyticsplus\ultralytics_utils.py:10
#       7 from sahi.prediction import ObjectPrediction, PredictionScore
#       8 from sahi.utils.cv import (get_bool_mask_from_coco_segmentation,
#       9                            read_image_as_pil, visualize_object_predictions)
# ---> 10 from ultralytics import YOLO as YOLOBase
#      11 from ultralytics.nn.tasks import attempt_load_one_weight
#      13 from ultralyticsplus.hf_utils import download_from_hub
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
#       3 __version__ = "8.0.21"
# ----> 5 from ultralytics.yolo.engine.model import YOLO
#       6 from ultralytics.yolo.utils import ops
#       7 from ultralytics.yolo.utils.checks import check_yolo as checks
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\yolo\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from . import v8
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\yolo\v8\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from ultralytics.yolo.v8 import classify, detect, segment
#       5 __all__ = ["classify", "segment", "detect"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\yolo\v8\classify\__init__.py:3
#       1 # Ultralytics YOLO 🚀, GPL-3.0 license
# ----> 3 from ultralytics.yolo.v8.classify.predict import ClassificationPredictor, predict
#       4 from ultralytics.yolo.v8.classify.train import ClassificationTrainer, train
#       5 from ultralytics.yolo.v8.classify.val import ClassificationValidator, val
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\yolo\v8\classify\predict.py:6
#       2 import sys
#       4 import torch
# ----> 6 from ultralytics.yolo.engine.predictor import BasePredictor
#       7 from ultralytics.yolo.engine.results import Results
#       8 from ultralytics.yolo.utils import DEFAULT_CFG, ROOT
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\yolo\engine\predictor.py:34
#      30 from pathlib import Path
#      32 import cv2
# ---> 34 from ultralytics.nn.autobackend import AutoBackend
#      35 from ultralytics.yolo.cfg import get_cfg
#      36 from ultralytics.yolo.data.dataloaders.stream_loaders import LoadImages, LoadPilAndNumpy, LoadScreenshots, LoadStreams
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\nn\autobackend.py:15
#      12 import torch.nn as nn
#      13 from PIL import Image
# ---> 15 from ultralytics.yolo.utils import LOGGER, ROOT, yaml_load
#      16 from ultralytics.yolo.utils.checks import check_requirements, check_suffix, check_version
#      17 from ultralytics.yolo.utils.downloads import attempt_download, is_url
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\yolo\utils\__init__.py:549
#     547 # Check first-install steps
#     548 PREFIX = colorstr("Ultralytics: ")
# --> 549 SETTINGS = get_settings()
#     550 DATASETS_DIR = Path(SETTINGS['datasets_dir'])  # global datasets directory
#     551 set_sentry()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\yolo\utils\__init__.py:499, in get_settings(file, version)
#     497 git_dir = get_git_dir()
#     498 root = git_dir or Path()
# --> 499 datasets_root = (root.parent if git_dir and is_dir_writeable(root.parent) else root).resolve()
#     500 defaults = {
#     501     'datasets_dir': str(datasets_root / 'datasets'),  # default datasets directory.
#     502     'weights_dir': str(root / 'weights'),  # default weights directory.
#    (...)
#     505     'uuid': uuid.getnode(),  # device UUID to align analytics
#     506     'settings_version': version}  # Ultralytics settings version
#     508 with torch_distributed_zero_first(RANK):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ultralytics\yolo\utils\__init__.py:261, in is_dir_writeable(dir_path)
#     251 """
#     252 Check if a directory is writeable.
#     253
#    (...)
#     258     bool: True if the directory is writeable, False otherwise.
#     259 """
#     260 try:
# --> 261     with tempfile.TemporaryFile(dir=dir_path):
#     262         pass
#     263     return True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\tempfile.py:559, in NamedTemporaryFile(mode, buffering, encoding, newline, suffix, prefix, dir, delete, errors)
#     557     return fd
#     558 try:
# --> 559     file = _io.open(dir, mode, buffering=buffering,
#     560                     newline=newline, encoding=encoding, errors=errors,
#     561                     opener=opener)
#     562     try:
#     563         raw = getattr(file, 'buffer', file)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\tempfile.py:556, in NamedTemporaryFile.<locals>.opener(*args)
#     554 def opener(*args):
#     555     nonlocal name
# --> 556     fd, name = _mkstemp_inner(dir, prefix, suffix, flags, output_type)
#     557     return fd
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2800.0_x64__qbz5n2kfra8p0\lib\tempfile.py:256, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     254 _sys.audit("tempfile.mkstemp", file)
#     255 try:
# --> 256     fd = _os.open(file, flags, 0o600)
#     257 except FileExistsError:
#     258     continue    # try again
#
# KeyboardInterrupt:
